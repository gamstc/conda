# %% [markdown]
# # Mein erstes Jupyter Notebook

# %% [markdown]
# Jupyter Notebooks bestehen aus einzelnen Zellen. Sowas wie Paragraphen, aber für unterschiedliche Inhalte. Texte/Erläuterungen und Code.
#
# Zellen hinzufügen ist einfach - einfach das Plus-Icon oben auswählen.

# %% [markdown]
# Anstatt kaum lesbare Kommentare im Code direkt zu verfassen, können wir vernünftig formatierte
# Erläuterungen hinzufügen.
#
# - zum Beispiel
# - eine Liste
#
# **Markdown** _auswählen nicht vergessen!_

# %% [markdown]
# ## Beispiel: Plot erstellen (mit Python)

# %% [markdown]
# Angenommen, wir wollen die Funktion
# \begin{align*}
# y=\sin(x) + \cos(x) &&\mbox{für } &&x\in [0;10\pi)&&&&&&
# \end{align*}
# plotten.

# %% [markdown]
# Im ersten Schritt müssen wir die benötigten Python-Bibliotheken importieren:

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# jetzt definieren wir die Funktion, die wir plotten möchten:

# %%
a = 1;
x = np.linspace(0, 10*np.pi, 10**3);
y = np.sin(a*x) + np.cos(x);

# %% [markdown]
# und nun noch der Plot-Befehl:

# %%
plt.plot(x,y);
plt.title('mein erster Plot');
